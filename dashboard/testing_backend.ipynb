# %% [markdown]
# # Generating dataset with "region" columns

# %%
import streamlit as st
import pandas as pd
import numpy as np
from PIL import Image
#from models import seqiahr_model

#import dashboard_data
#import dashboard_models
BRASIL_IO_URL = "https://brasil.io/dataset/covid19/caso?format=csv"

REGIONS_DICT = {"Sudeste":["SP","RJ","MG","ES"], "Nordeste":["BA","PE","CE","RN","PB","AL","SE","PI","MA"],
               "Sul":["RS","SC","PR"], "Centro-Oeste":["GO","MT","MS","DF"], "Norte":["PA","AM","RO","RR","TO","AC","AP"]}

def get_data():
    brasil_io_url = BRASIL_IO_URL
    cases = pd.read_csv(brasil_io_url).rename(
        columns={"confirmed": "Casos Confirmados"})

    return cases

def get_data_uf(data, uf, city_options):
    if uf:
        data = data.loc[data.state.isin(uf)]
        if city_options:
            city_options = [c.split(" - ")[1] for c in city_options]
            data = data.loc[
                (data.city.isin(city_options)) & (data.place_type == "city")
            ][["date", "state", "city", "Casos Confirmados"]]
            pivot_data = data.pivot_table(values="Casos Confirmados", index="date", columns="city")
            data = pd.DataFrame(pivot_data.to_records())
        else:
            data = data.loc[data.place_type == "state"][["date", "state", "Casos Confirmados"]]
            pivot_data = data.pivot_table(values="Casos Confirmados", index="date", columns="state")
            data = pd.DataFrame(pivot_data.to_records())

    else:
        return data.loc[data.place_type == "city"].groupby("date")["Casos Confirmados"].sum().to_frame()

    return data.set_index("date")

def get_aligned_data(df,align=100):
    align_dfs = [df.loc[df[c]>=100,[c]].values.reshape(-1,) for c in df.columns] 
    columns = [c for c in df.columns] 
    aligned_df = pd.DataFrame(align_dfs,index=columns).T                           
    #align_dfs = [d.reset_index() for d in align_dfs]
    #aligned = pd.concat([d for d in align_dfs],ignore_index=True)
    return aligned_df

def get_city_list(data, uf):
    data_filt = data.loc[(data.state.isin(uf)) & (data.place_type == "city")]
    data_filt["state_city"] = data_filt["state"] + " - " + data_filt["city"]
    return sorted(list(data_filt.state_city.drop_duplicates().values))

def get_data_region(source=BRASIL_IO_URL):
    cases = pd.read_csv(source).rename(
        columns={"confirmed": "Casos Confirmados"})
    
    return cases

# %%
cases = get_data_region()
cases
# Out:
#             date state                    city place_type  Casos Confirmados  \
# 0     2020-04-09    AM                   Anori       city                  1
# 1     2020-04-09    AM            Boca do Acre       city                  1
# 2     2020-04-09    AM       Careiro da Várzea       city                  2
# 3     2020-04-09    AM  Importados/Indefinidos       city                  0
# 4     2020-04-09    AM                Iranduba       city                 11
# ...          ...   ...                     ...        ...                ...
# 8848  2020-02-27    SP               São Paulo       city                  1
# 8849  2020-02-27    SP                     NaN      state                  1
# 8850  2020-02-26    SP                     NaN      state                  1
# 8851  2020-02-25    SP               São Paulo       city                  1
# 8852  2020-02-25    SP                     NaN      state                  1
#
#       deaths  is_last  estimated_population_2019  city_ibge_code  \
# 0        0.0     True                    21010.0       1300102.0
# 1        0.0     True                    34308.0       1300706.0
# 2        0.0     True                    30225.0       1301159.0
# 3        0.0     True                        NaN             NaN
# 4        0.0     True                    48296.0       1301852.0
# ...      ...      ...                        ...             ...
# 8848     NaN    False                 12252023.0       3550308.0
# 8849     0.0    False                 45919049.0            35.0
# 8850     0.0    False                 45919049.0            35.0
# 8851     NaN    False                 12252023.0       3550308.0
# 8852     0.0    False                 45919049.0            35.0
#
#       confirmed_per_100k_inhabitants  death_rate
# 0                            4.75964         NaN
# 1                            2.91477         NaN
# 2                            6.61704         NaN
# 3                                NaN         NaN
# 4                           22.77621         NaN
# ...                              ...         ...
# 8848                         0.00816         NaN
# 8849                         0.00218         NaN
# 8850                         0.00218         NaN
# 8851                         0.00816         NaN
# 8852                         0.00218         NaN
#
# [8853 rows x 11 columns]

# %%
cases.shape
# Out:
# (8853, 11)

# %%
regions = {"CO": ["DF", "GO", "MS", "MT"], "N": ["AC", "AM", "PA", "RO", "RR", "TO", "AP"], 
           "NE": ["AL", "BA", "CE", "MA", "PB", "PE", "PI", "RN", "SE",], "S": ["PR", "RS", "SC"],
           "SE": ["ES", "MG", "RJ", "SP"]}
state_to_regions_dict = {"AC":"N", "AM":"N", "PA":"N", "RO":"N", "RR":"N", "TO":"N", "AP":"N",
                         "AL":"NE", "BA":"NE", "CE":"NE", "MA":"NE", "PB":"NE", "PE":"NE", "PI":"NE", "RN":"NE", "SE":"NE",
                         "DF":"CO", "GO":"CO", "MS":"CO", "MT":"CO",
                         "PR":"S", "RS":"S", "SC":"S",
                         "ES":"SE", "MG":"SE", "RJ":"SE", "SP":"SE"}
cases
# Out:
#             date state                    city place_type  confirmed  deaths  \
# 0     2020-04-09    AM                   Anori       city          1     0.0
# 1     2020-04-09    AM            Boca do Acre       city          1     0.0
# 2     2020-04-09    AM       Careiro da Várzea       city          2     0.0
# 3     2020-04-09    AM  Importados/Indefinidos       city          0     0.0
# 4     2020-04-09    AM                Iranduba       city         11     0.0
# ...          ...   ...                     ...        ...        ...     ...
# 8848  2020-02-27    SP               São Paulo       city          1     NaN
# 8849  2020-02-27    SP                     NaN      state          1     0.0
# 8850  2020-02-26    SP                     NaN      state          1     0.0
# 8851  2020-02-25    SP               São Paulo       city          1     NaN
# 8852  2020-02-25    SP                     NaN      state          1     0.0
#
#       is_last  estimated_population_2019  city_ibge_code  \
# 0        True                    21010.0       1300102.0
# 1        True                    34308.0       1300706.0
# 2        True                    30225.0       1301159.0
# 3        True                        NaN             NaN
# 4        True                    48296.0       1301852.0
# ...       ...                        ...             ...
# 8848    False                 12252023.0       3550308.0
# 8849    False                 45919049.0            35.0
# 8850    False                 45919049.0            35.0
# 8851    False                 12252023.0       3550308.0
# 8852    False                 45919049.0            35.0
#
#       confirmed_per_100k_inhabitants  death_rate
# 0                            4.75964         NaN
# 1                            2.91477         NaN
# 2                            6.61704         NaN
# 3                                NaN         NaN
# 4                           22.77621         NaN
# ...                              ...         ...
# 8848                         0.00816         NaN
# 8849                         0.00218         NaN
# 8850                         0.00218         NaN
# 8851                         0.00816         NaN
# 8852                         0.00218         NaN
#
# [8853 rows x 11 columns]

# %%
if "region" not in cases.columns:
    column_ix = cases.columns.get_loc("city")+1
    cases.insert(loc= column_ix,column="region",value=np.nan)
    for ix,s in enumerate(cases.state):
        cases.iloc[ix:,column_ix] = state_to_regions_dict[s]
cases
# Out:
#             date state                    city region place_type  confirmed  \
# 0     2020-04-09    AM                   Anori      N       city          1
# 1     2020-04-09    AM            Boca do Acre      N       city          1
# 2     2020-04-09    AM       Careiro da Várzea      N       city          2
# 3     2020-04-09    AM  Importados/Indefinidos      N       city          0
# 4     2020-04-09    AM                Iranduba      N       city         11
# ...          ...   ...                     ...    ...        ...        ...
# 8848  2020-02-27    SP               São Paulo     SE       city          1
# 8849  2020-02-27    SP                     NaN     SE      state          1
# 8850  2020-02-26    SP                     NaN     SE      state          1
# 8851  2020-02-25    SP               São Paulo     SE       city          1
# 8852  2020-02-25    SP                     NaN     SE      state          1
#
#       deaths  is_last  estimated_population_2019  city_ibge_code  \
# 0        0.0     True                    21010.0       1300102.0
# 1        0.0     True                    34308.0       1300706.0
# 2        0.0     True                    30225.0       1301159.0
# 3        0.0     True                        NaN             NaN
# 4        0.0     True                    48296.0       1301852.0
# ...      ...      ...                        ...             ...
# 8848     NaN    False                 12252023.0       3550308.0
# 8849     0.0    False                 45919049.0            35.0
# 8850     0.0    False                 45919049.0            35.0
# 8851     NaN    False                 12252023.0       3550308.0
# 8852     0.0    False                 45919049.0            35.0
#
#       confirmed_per_100k_inhabitants  death_rate
# 0                            4.75964         NaN
# 1                            2.91477         NaN
# 2                            6.61704         NaN
# 3                                NaN         NaN
# 4                           22.77621         NaN
# ...                              ...         ...
# 8848                         0.00816         NaN
# 8849                         0.00218         NaN
# 8850                         0.00218         NaN
# 8851                         0.00816         NaN
# 8852                         0.00218         NaN
#
# [8853 rows x 12 columns]

# %%
cases.shape
# Out:
# (7059, 12)

# %%
cases.iloc[234:435,:]
# Out:
#            date state             city region place_type  confirmed  deaths  \
# 234  2020-04-06    MT              NaN     CO      state         76     1.0
# 235  2020-04-06    PA       Abaetetuba      N       city          1     0.0
# 236  2020-04-06    PA         Altamira      N       city          2     0.0
# 237  2020-04-06    PA       Ananindeua      N       city         14     0.0
# 238  2020-04-06    PA        Barcarena      N       city          3     0.0
# ..          ...   ...              ...    ...        ...        ...     ...
# 430  2020-04-06    RS      Dois Irmãos      S       city          2     0.0
# 431  2020-04-06    RS      Dom Pedrito      S       city          1     0.0
# 432  2020-04-06    RS  Eldorado do Sul      S       city          1     0.0
# 433  2020-04-06    RS          Erechim      S       city          3     0.0
# 434  2020-04-06    RS   Estância Velha      S       city          3     0.0
#
#      is_last  estimated_population_2019  city_ibge_code  \
# 234     True                  3484466.0            51.0
# 235     True                   157698.0       1500107.0
# 236     True                   114594.0       1500602.0
# 237     True                   530598.0       1500800.0
# 238     True                   124680.0       1501303.0
# ..       ...                        ...             ...
# 430     True                    32671.0       4306403.0
# 431     True                    38461.0       4306601.0
# 432     True                    41285.0       4306767.0
# 433     True                   105862.0       4307005.0
# 434     True                    50022.0       4307609.0
#
#      confirmed_per_100k_inhabitants  death_rate
# 234                         2.18111      0.0132
# 235                         0.63412         NaN
# 236                         1.74529         NaN
# 237                         2.63853         NaN
# 238                         2.40616         NaN
# ..                              ...         ...
# 430                         6.12164         NaN
# 431                         2.60004         NaN
# 432                         2.42219         NaN
# 433                         2.83388         NaN
# 434                         5.99736         NaN
#
# [201 rows x 12 columns]

# %%
bool_mask = cases.loc[:,"place_type"]=="state"
cases.loc[bool_mask,:]#.sum()
# Out:
#             date state city region place_type  confirmed  deaths  is_last  \
# 4     2020-04-06    AC  NaN      N      state         50     1.0     True
# 10    2020-04-06    AL  NaN     NE      state         31     2.0     True
# 25    2020-04-06    AM  NaN      N      state        532    19.0     True
# 30    2020-04-06    AP  NaN      N      state         39     3.0     True
# 84    2020-04-06    BA  NaN     NE      state        437    10.0     True
# ...          ...   ...  ...    ...        ...        ...     ...      ...
# 7050  2020-03-01    SP  NaN     SE      state          2     NaN    False
# 7052  2020-02-29    SP  NaN     SE      state          2     NaN    False
# 7054  2020-02-28    SP  NaN     SE      state          2     NaN    False
# 7056  2020-02-27    SP  NaN     SE      state          1     NaN    False
# 7058  2020-02-26    SP  NaN     SE      state          1     NaN    False
#
#       estimated_population_2019  city_ibge_code  \
# 4                      881935.0            12.0
# 10                    3337357.0            27.0
# 25                    4144597.0            13.0
# 30                     845731.0            16.0
# 84                   14873064.0            29.0
# ...                         ...             ...
# 7050                 45919049.0            35.0
# 7052                 45919049.0            35.0
# 7054                 45919049.0            35.0
# 7056                 45919049.0            35.0
# 7058                 45919049.0            35.0
#
#       confirmed_per_100k_inhabitants  death_rate
# 4                            5.66935      0.0200
# 10                           0.92888      0.0645
# 25                          12.83599      0.0357
# 30                           4.61140      0.0769
# 84                           2.93820      0.0229
# ...                              ...         ...
# 7050                         0.00436         NaN
# 7052                         0.00436         NaN
# 7054                         0.00436         NaN
# 7056                         0.00218         NaN
# 7058                         0.00218         NaN
#
# [625 rows x 12 columns]

# %% [markdown]
# ## Grouping by date, region, state, city

# %%
data = cases.loc[cases.loc[:,"region"] == "CO",:]
#df = cases.groupby(["date"]).loc[:,"region"]
data
# Out:
#             date state                   city region place_type  confirmed  \
# 85    2020-04-06    DF               Brasília     CO       city        485
# 86    2020-04-06    DF                    NaN     CO      state        485
# 109   2020-04-06    GO  Águas Lindas de Goiás     CO       city          1
# 110   2020-04-06    GO               Anápolis     CO       city          8
# 111   2020-04-06    GO   Aparecida de Goiânia     CO       city          1
# ...          ...   ...                    ...    ...        ...        ...
# 7003  2020-03-09    DF                    NaN     CO      state          1
# 7012  2020-03-08    DF               Brasília     CO       city          1
# 7013  2020-03-08    DF                    NaN     CO      state          1
# 7025  2020-03-07    DF               Brasília     CO       city          1
# 7026  2020-03-07    DF                    NaN     CO      state          1
#
#       deaths  is_last  estimated_population_2019  city_ibge_code  \
# 85      10.0     True                  3015268.0       5300108.0
# 86      10.0     True                  3015268.0            53.0
# 109      0.0     True                   212440.0       5200258.0
# 110      0.0     True                   386923.0       5201108.0
# 111      0.0     True                   578179.0       5201405.0
# ...      ...      ...                        ...             ...
# 7003     0.0    False                  3015268.0            53.0
# 7012     0.0    False                  3015268.0       5300108.0
# 7013     0.0    False                  3015268.0            53.0
# 7025     0.0    False                  3015268.0       5300108.0
# 7026     0.0    False                  3015268.0            53.0
#
#       confirmed_per_100k_inhabitants  death_rate
# 85                          16.08481      0.0206
# 86                          16.08481      0.0206
# 109                          0.47072         NaN
# 110                          2.06759         NaN
# 111                          0.17296         NaN
# ...                              ...         ...
# 7003                         0.03316         NaN
# 7012                         0.03316         NaN
# 7013                         0.03316         NaN
# 7025                         0.03316         NaN
# 7026                         0.03316         NaN
#
# [586 rows x 12 columns]

# %%
def get_data_uf(data, uf, city_option):
    if uf != WHOLE_BRASIL:
        data = data.loc[data.state == uf]
        if city_option and city_option != "Todos":
            data = data.loc[data.city == city_option]

    return data.groupby("date")["Casos Confirmados"].sum()

# %%
cases.loc[cases.date=="2020-02-26",:]
# Out:
#             date state       city region place_type  confirmed  deaths  \
# 7057  2020-02-26    SP  São Paulo     SE       city          1     NaN
# 7058  2020-02-26    SP        NaN     SE      state          1     NaN
#
#       is_last  estimated_population_2019  city_ibge_code  \
# 7057    False                 12252023.0       3550308.0
# 7058    False                 45919049.0            35.0
#
#       confirmed_per_100k_inhabitants  death_rate
# 7057                         0.00816         NaN
# 7058                         0.00218         NaN

# %%
cases.groupby("date").sum()
# Out:
#             confirmed  deaths  is_last  estimated_population_2019  \
# date
# 2020-02-26          2     0.0      0.0                 58171072.0
# 2020-02-27          2     0.0      0.0                 58171072.0
# 2020-02-28          4     0.0      0.0                 58171072.0
# 2020-02-29          4     0.0      0.0                 58171072.0
# 2020-03-01          4     0.0      0.0                 58171072.0
# 2020-03-02          4     0.0      0.0                 58171072.0
# 2020-03-03          4     0.0      0.0                 58171072.0
# 2020-03-04          6     0.0      0.0                 58171072.0
# 2020-03-05         15     0.0      0.0                 79639077.0
# 2020-03-06         17     0.0      0.0                 89593893.0
# 2020-03-07         33     0.0      0.0                 83847641.0
# 2020-03-08         45     0.0      0.0                118291289.0
# 2020-03-09         43     0.0      0.0                109610967.0
# 2020-03-10         51     0.0      0.0                121054918.0
# 2020-03-11         77     0.0      0.0                118182384.0
# 2020-03-12        176     0.0      0.0                197686580.0
# 2020-03-13         66     0.0      0.0                122107353.0
# 2020-03-14        196     0.0      0.0                130165790.0
# 2020-03-15        138     0.0      0.0                 89049873.0
# 2020-03-16        540     0.0      0.0                224352346.0
# 2020-03-17        526     2.0      0.0                179945310.0
# 2020-03-18       1016     3.0      0.0                251914303.0
# 2020-03-19       1215    14.0      0.0                244977698.0
# 2020-03-20       1644    18.0      0.0                253021807.0
# 2020-03-21       1844    21.0      0.0                257906870.0
# 2020-03-22       2452    28.0      0.0                257801077.0
# 2020-03-23       3095    38.0      0.0                258135919.0
# 2020-03-24       3700    54.0      0.0                275172845.0
# 2020-03-25       5123   118.0      0.0                300611134.0
# 2020-03-26       5943   154.0      0.0                300501529.0
# 2020-03-27       6952   186.0      0.0                306802998.0
# 2020-03-28       6446   146.0      0.0                277043023.0
# 2020-03-29       6943   172.0      0.0                269710187.0
# 2020-03-30       9320   332.0      1.0                316157883.0
# 2020-03-31      11648   404.0      0.0                320857281.0
# 2020-04-01      13862   488.0      0.0                325023649.0
# 2020-04-02      16196   589.0      0.0                328981454.0
# 2020-04-03      18424   730.0      2.0                332737626.0
# 2020-04-04      20552   883.0     31.0                332722420.0
# 2020-04-05      20858   916.0     24.0                318964129.0
# 2020-04-06      21876  1048.0    655.0                316060033.0
#
#             city_ibge_code  confirmed_per_100k_inhabitants  death_rate
# date
# 2020-02-26    3.550343e+06                         0.01034      0.0000
# 2020-02-27    3.550343e+06                         0.01034      0.0000
# 2020-02-28    3.550343e+06                         0.02068      0.0000
# 2020-02-29    3.550343e+06                         0.02068      0.0000
# 2020-03-01    3.550343e+06                         0.02068      0.0000
# 2020-03-02    3.550343e+06                         0.02068      0.0000
# 2020-03-03    3.550343e+06                         0.02068      0.0000
# 2020-03-04    3.550343e+06                         0.03102      0.0000
# 2020-03-05    6.850815e+06                         0.63497      0.0000
# 2020-03-06    9.515893e+06                         0.78474      0.0000
# 2020-03-07    1.530867e+07                         1.27329      0.0000
# 2020-03-08    2.482950e+07                         2.10758      0.0000
# 2020-03-09    2.113534e+07                         1.85689      0.0000
# 2020-03-10    2.543928e+07                         3.39568      0.0000
# 2020-03-11    2.704986e+07                         3.69321      0.0000
# 2020-03-12    7.847985e+07                         9.03234      0.0000
# 2020-03-13    6.509472e+07                         6.82527      0.0000
# 2020-03-14    6.543377e+07                        76.59397      0.0000
# 2020-03-15    5.592036e+07                        77.86252      0.0000
# 2020-03-16    1.390331e+08                        93.21188      0.0000
# 2020-03-17    1.460968e+08                       102.70817      0.0125
# 2020-03-18    2.420228e+08                       136.80520      0.0125
# 2020-03-19    2.763620e+08                       158.83415      1.2100
# 2020-03-20    3.650687e+08                       221.64148      0.0521
# 2020-03-21    3.702145e+08                       296.45206      1.4964
# 2020-03-22    3.961487e+08                       317.91328      1.4843
# 2020-03-23    5.227805e+08                       450.44565      1.4955
# 2020-03-24    6.065096e+08                       588.47925      2.0179
# 2020-03-25    7.925758e+08                       770.61142      3.6627
# 2020-03-26    8.604463e+08                       898.22720      6.1926
# 2020-03-27    9.669404e+08                      1108.62682      6.5965
# 2020-03-28    8.998440e+08                      1196.74755      5.0792
# 2020-03-29    9.481544e+08                      1244.10930      3.8996
# 2020-03-30    1.255025e+09                      1606.29663     11.0540
# 2020-03-31    1.410272e+09                      1919.60469     13.0839
# 2020-04-01    1.540072e+09                      2153.96761     18.5647
# 2020-04-02    1.703893e+09                      2651.23862     15.3421
# 2020-04-03    1.873402e+09                      3198.52868     24.5475
# 2020-04-04    1.959928e+09                      3530.93397     34.1411
# 2020-04-05    2.044475e+09                      4025.83297     33.1910
# 2020-04-06    2.167196e+09                      4449.09504     36.9036

# %%
cases.loc[(cases.date=="2020-02-26")&(cases.state=="SP"),:]
# Out:
#             date state       city region place_type  confirmed  deaths  \
# 7057  2020-02-26    SP  São Paulo     SE       city          1     NaN
# 7058  2020-02-26    SP        NaN     SE      state          1     NaN
#
#       is_last  estimated_population_2019  city_ibge_code  \
# 7057    False                 12252023.0       3550308.0
# 7058    False                 45919049.0            35.0
#
#       confirmed_per_100k_inhabitants  death_rate
# 7057                         0.00816         NaN
# 7058                         0.00218         NaN

# %%
cases.loc[(cases.date=="2020-02-26")&(cases.state=="SP"),:].groupby("date").sum()
# Out:
#             confirmed  deaths  is_last  estimated_population_2019  \
# date
# 2020-02-26          2     0.0    False                 58171072.0
#
#             city_ibge_code  confirmed_per_100k_inhabitants  death_rate
# date
# 2020-02-26       3550343.0                         0.01034         0.0

# %%
#def get_data_uf(data, uf, city_option):
#    if uf != WHOLE_BRASIL:
#        data = data.loc[data.state == uf]
#        if city_option and city_option != "Todos":
#            data = data.loc[data.city == city_option]

#    return data.groupby("date")["Casos Confirmados"].sum()

############################### my changes ############################################ 
state_to_regions_dict = {"AC":"N", "AM":"N", "PA":"N", "RO":"N", "RR":"N", "TO":"N", "AP":"N",
                         "AL":"NE", "BA":"NE", "CE":"NE", "MA":"NE", "PB":"NE", "PE":"NE", "PI":"NE", "RN":"NE", "SE":"NE",
                         "DF":"CO", "GO":"CO", "MS":"CO", "MT":"CO",
                         "PR":"S", "RS":"S", "SC":"S",
                         "ES":"SE", "MG":"SE", "RJ":"SE", "SP":"SE"}
WHOLE_BRAZIL="Brasil inteiro"
def get_data_region(data, region=None, uf=None, city_option=None):
    if region:
        if "region" not in data.columns:
            column_ix = cases.columns.get_loc("date")+1
        cases.insert(loc= column_ix,column="region",value=np.nan)
        for ix,s in enumerate(cases.state):
            cases.iloc[ix:,column_ix] = state_to_regions_dict[s]
        data = data.loc[(data.region == region)&(data.place_type=="state"),:]
    if uf:
        data = data.loc[(data.state==uf)&(data.place_type=="state"),:]
    if city_option:
        data = data.loc[(data.city==city)&(data.place_type=="city"),:]
    return data.groupby("date")["Casos Confirmados"].sum()

        
        
        
#######################################################################################

# %%
type(cases.loc[(cases.date=="2020-02-26")&(cases.state=="SP"),"city"].iloc[1])
# Out:
# float

# %%
len(cases.loc[(cases.date=="2020-03-26")&(cases.city.isna()),:])
# Out:
# 26

# %%
cases.loc[(cases.date=="2020-02-26")&(cases.state=="RJ"),:].groupby("date").sum()
# Out:
# Empty DataFrame
# Columns: [confirmed, deaths, is_last, estimated_population_2019, city_ibge_code, confirmed_per_100k_inhabitants, death_rate]
# Index: []

# %% [markdown]
# ## Testing get_data_region

# %%
cases = get_data_region()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-9bab245da5d5> in <module>
# ----> 1 cases = get_data_region()
#
# NameError: name 'get_data_region' is not defined
